# %%
import pandas as pd

# %%
#To get the list of samples
f = open("/home/jimitcard/Desktop/OMR/sampled_1250/samples_1250_list.txt", "r")
samples=f.read().strip().split("\n")
print(len(samples))
f.close()
# Out:
# 1250

# %%
#to get the vocabulary of samples
vocabulary=set({})
for sample in samples:
    if len(vocabulary)==60:
        break
    f = open("/home/jimitcard/Desktop/OMR/sampled_1250/"+sample+"/"+sample+".semantic", "r")
    notes=f.read().strip().split("\t")
    for note in notes:
        vocabulary.add(note)
print(len(vocabulary))
# Out:
# 60

# %%
vocabulary=list(vocabulary)
vocabulary
# Out:
# ['rest-half',
#  'note-G4_quarter',
#  'note-C5_quarter',
#  'note-A4_quarter',
#  'keySignature-GM',
#  'timeSignature-3/8',
#  'timeSignature-3/4',
#  'note-F5_quarter',
#  'keySignature-EbM',
#  'timeSignature-2/4',
#  'keySignature-BbM',
#  'multirest-1',
#  'note-E5_quarter',
#  'note-E5_sixteenth',
#  'note-F5_sixteenth',
#  'note-G5_sixteenth',
#  'note-D5_eighth',
#  'note-A4_sixteenth',
#  'note-Bb4_sixteenth',
#  'note-Ab4_eighth',
#  'note-B4_sixteenth',
#  'note-C5_sixteenth',
#  'note-Ab4_sixteenth',
#  'clef-C1',
#  'note-Eb4_sixteenth',
#  'note-Eb5_eighth',
#  'note-Bb4_eighth',
#  'rest-eighth',
#  'timeSignature-C',
#  'tie',
#  'barline',
#  'note-F4_sixteenth',
#  'note-G4_sixteenth',
#  'note-C5_eighth',
#  'keySignature-FM',
#  'note-E5_eighth',
#  'note-G5_eighth',
#  'note-B4_eighth',
#  'clef-G2',
#  'note-Eb4_eighth',
#  'timeSignature-6/8',
#  'note-A5_sixteenth',
#  'note-G4_eighth',
#  'note-F5_eighth',
#  'timeSignature-C/',
#  'note-F4_eighth',
#  'note-Eb5_sixteenth',
#  'rest-sixteenth',
#  'note-C4_sixteenth',
#  'note-F4_quarter',
#  'note-B4_quarter',
#  'note-E4_sixteenth',
#  'note-C4_eighth',
#  'note-G5_quarter',
#  'note-A4_eighth',
#  'note-A5_eighth',
#  'rest-quarter',
#  'note-Bb4_quarter',
#  'note-D5_sixteenth',
#  'note-D4_sixteenth']

# %%
#now create a pandas with samples and vocab and populate for frequency
sample_1250 = pd.DataFrame(index=samples, columns=vocabulary)
sample_1250 = sample_1250.fillna(0) # with 0s rather than NaNs
sample_1250.head()
# Out:
#                  rest-half  note-G4_quarter  note-C5_quarter  note-A4_quarter  \
# 000100537-1_1_1          0                0                0                0
# 000100556-1_1_1          0                0                0                0
# 000100593-1_1_1          0                0                0                0
# 000100596-1_1_1          0                0                0                0
# 000100602-1_1_1          0                0                0                0
#
#                  keySignature-GM  timeSignature-3/8  timeSignature-3/4  \
# 000100537-1_1_1                0                  0                  0
# 000100556-1_1_1                0                  0                  0
# 000100593-1_1_1                0                  0                  0
# 000100596-1_1_1                0                  0                  0
# 000100602-1_1_1                0                  0                  0
#
#                  note-F5_quarter  keySignature-EbM  timeSignature-2/4  ...  \
# 000100537-1_1_1                0                 0                  0  ...
# 000100556-1_1_1                0                 0                  0  ...
# 000100593-1_1_1                0                 0                  0  ...
# 000100596-1_1_1                0                 0                  0  ...
# 000100602-1_1_1                0                 0                  0  ...
#
#                  note-B4_quarter  note-E4_sixteenth  note-C4_eighth  \
# 000100537-1_1_1                0                  0               0
# 000100556-1_1_1                0                  0               0
# 000100593-1_1_1                0                  0               0
# 000100596-1_1_1                0                  0               0
# 000100602-1_1_1                0                  0               0
#
#                  note-G5_quarter  note-A4_eighth  note-A5_eighth  \
# 000100537-1_1_1                0               0               0
# 000100556-1_1_1                0               0               0
# 000100593-1_1_1                0               0               0
# 000100596-1_1_1                0               0               0
# 000100602-1_1_1                0               0               0
#
#                  rest-quarter  note-Bb4_quarter  note-D5_sixteenth  \
# 000100537-1_1_1             0                 0                  0
# 000100556-1_1_1             0                 0                  0
# 000100593-1_1_1             0                 0                  0
# 000100596-1_1_1             0                 0                  0
# 000100602-1_1_1             0                 0                  0
#
#                  note-D4_sixteenth
# 000100537-1_1_1                  0
# 000100556-1_1_1                  0
# 000100593-1_1_1                  0
# 000100596-1_1_1                  0
# 000100602-1_1_1                  0
#
# [5 rows x 60 columns]

# %%
for sample in samples:
    f = open("/home/jimitcard/Desktop/OMR/sampled_1250/"+sample+"/"+sample+".semantic", "r")
    notes=f.read().strip().split("\t")
    for note in notes:
        sample_1250.loc[sample,note] +=1
sample_1250.head()
# Out:
#                  rest-half  note-G4_quarter  note-C5_quarter  note-A4_quarter  \
# 000100537-1_1_1          0                0                0                0
# 000100556-1_1_1          0                3                3                2
# 000100593-1_1_1          0                0                0                0
# 000100596-1_1_1          0                0                1                0
# 000100602-1_1_1          0                0                3                0
#
#                  keySignature-GM  timeSignature-3/8  timeSignature-3/4  \
# 000100537-1_1_1                0                  0                  0
# 000100556-1_1_1                0                  0                  1
# 000100593-1_1_1                1                  0                  0
# 000100596-1_1_1                0                  0                  0
# 000100602-1_1_1                0                  0                  0
#
#                  note-F5_quarter  keySignature-EbM  timeSignature-2/4  ...  \
# 000100537-1_1_1                0                 0                  0  ...
# 000100556-1_1_1                0                 0                  0  ...
# 000100593-1_1_1                0                 0                  1  ...
# 000100596-1_1_1                0                 0                  0  ...
# 000100602-1_1_1                1                 0                  0  ...
#
#                  note-B4_quarter  note-E4_sixteenth  note-C4_eighth  \
# 000100537-1_1_1                0                  0               0
# 000100556-1_1_1                2                  0               0
# 000100593-1_1_1                0                  0               0
# 000100596-1_1_1                0                  0               0
# 000100602-1_1_1                1                  0               0
#
#                  note-G5_quarter  note-A4_eighth  note-A5_eighth  \
# 000100537-1_1_1                0               0               0
# 000100556-1_1_1                0               0               0
# 000100593-1_1_1                0               2               0
# 000100596-1_1_1                0               2               0
# 000100602-1_1_1                0               0               0
#
#                  rest-quarter  note-Bb4_quarter  note-D5_sixteenth  \
# 000100537-1_1_1             0                 0                  0
# 000100556-1_1_1             2                 0                  0
# 000100593-1_1_1             0                 0                  0
# 000100596-1_1_1             1                 3                  0
# 000100602-1_1_1             0                 0                  0
#
#                  note-D4_sixteenth
# 000100537-1_1_1                  0
# 000100556-1_1_1                  0
# 000100593-1_1_1                  0
# 000100596-1_1_1                  0
# 000100602-1_1_1                  0
#
# [5 rows x 60 columns]

# %%
frequency_of_notes=sample_1250.sum(numeric_only=True, axis = 0, skipna = True) 
sorted_frequency=frequency_of_notes.sort_values(axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last')
sorted_frequency
# Out:
# barline               4028
# note-C5_eighth        2319
# note-D5_eighth        1616
# note-C5_sixteenth     1424
# note-G4_eighth        1208
# note-D5_sixteenth     1189
# note-A4_eighth        1114
# note-Bb4_eighth        960
# note-B4_eighth         901
# rest-eighth            890
# clef-G2                819
# note-E5_eighth         788
# note-E5_sixteenth      741
# note-G4_sixteenth      719
# note-F5_eighth         701
# note-A4_sixteenth      680
# note-F5_sixteenth      633
# note-Bb4_sixteenth     627
# rest-quarter           591
# note-C5_quarter        583
# note-B4_sixteenth      564
# note-F4_eighth         560
# timeSignature-C        548
# note-F4_sixteenth      520
# note-G5_eighth         447
# clef-C1                437
# note-G5_sixteenth      341
# keySignature-FM        311
# note-A4_quarter        299
# note-Eb5_eighth        297
# timeSignature-2/4      270
# note-G4_quarter        259
# note-Bb4_quarter       250
# note-Eb5_sixteenth     222
# note-E4_sixteenth      220
# keySignature-BbM       182
# rest-sixteenth         176
# note-E5_quarter        164
# note-C4_sixteenth      157
# note-B4_quarter        156
# note-D4_sixteenth      154
# note-F4_quarter        145
# note-F5_quarter        145
# note-Eb4_sixteenth     140
# timeSignature-3/8      132
# keySignature-GM        131
# note-Ab4_eighth        119
# rest-half              118
# timeSignature-6/8      111
# timeSignature-3/4      111
# keySignature-EbM       110
# note-A5_eighth         105
# note-G5_quarter        102
# note-A5_sixteenth      100
# note-Ab4_sixteenth      96
# note-Eb4_eighth         95
# note-C4_eighth          86
# timeSignature-C/        80
# multirest-1             75
# tie                     59
# dtype: int64

# %%
sorted_frequency.describe()
# Out:
# count      60.000000
# mean      518.750000
# std       640.590131
# min        59.000000
# 25%       131.750000
# 50%       283.500000
# 75%       685.250000
# max      4028.000000
# dtype: float64

# %% [markdown]
# # Bar Graph

# %%
#plotting bar graph with bins of different colors
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# ('Matplotlib version: ', '2.2.5')

# %%
counts=[]
for frequency in sorted_frequency:
    counts.append(frequency)

# %%
counts
# Out:
# [4028,
#  2319,
#  1616,
#  1424,
#  1208,
#  1189,
#  1114,
#  960,
#  901,
#  890,
#  819,
#  788,
#  741,
#  719,
#  701,
#  680,
#  633,
#  627,
#  591,
#  583,
#  564,
#  560,
#  548,
#  520,
#  447,
#  437,
#  341,
#  311,
#  299,
#  297,
#  270,
#  259,
#  250,
#  222,
#  220,
#  182,
#  176,
#  164,
#  157,
#  156,
#  154,
#  145,
#  145,
#  140,
#  132,
#  131,
#  119,
#  118,
#  111,
#  111,
#  110,
#  105,
#  102,
#  100,
#  96,
#  95,
#  86,
#  80,
#  75,
#  59]

# %%
bins_label=[]
for i in range(0,6):
    bins_label.append('HF Samples')
for i in range(6,54):
    bins_label.append('Normal Samples')
for i in range(54,60):
    bins_label.append('LF Samples')

# %%
f, ax = plt.subplots(figsize=(15,5)) # set the size that you'd like (width, height)

barlist=plt.bar(sorted_frequency.index,counts)
plt.xticks([])

for i in range(0,6):
    barlist[i].set_color('darkred')
for i in range(6,54):
    barlist[i].set_color('lightgray')
for i in range(54,60):
    barlist[i].set_color('darkorange')
plt.yscale('log')
colors = {'HF samples':'darkred', 'Normal Samples':'lightgray','LF Samples':'darkorange'}         
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),10,10, color=colors[label]) for label in labels]
plt.legend(handles, labels)
plt.ylabel('Frequency (Log Scale)')
plt.xlabel('Notes arranged in ascending order of frequency of occurrence')
plt.title('Bin formation of Low Frequency, High Frequency and Normal Samples')
plt.savefig('barGraph.png')

plt.show()

# %%
SMALL_SIZE = 16
MEDIUM_SIZE = 9
BIGGER_SIZE = 14

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %% [markdown]
# # Frequency of notes

# %%
f, ax = plt.subplots(figsize=(15,5)) # set the size that you'd like (width, height)
sorted_frequency.plot(kind='line')

plt.title('Frequency Distribution of Notes in Sampled Dataset')
plt.ylabel('Frequency')
plt.xlabel('Notes')
plt.xticks([])

plt.savefig('frequencyVsNotes.png')
#plt.plot([5,0], [5,4500], 'k-')
#plt.yscale('log')
#median
#10-90
plt.show()

# %%
import matplotlib.lines as mlines

red_square = dict(markerfacecolor='r', marker='^')
fig6, ax6 = plt.subplots(figsize=(15,5))
ax6.set_title('Box Plot: Outliers represents LF and HF samples')
ax6.boxplot(sorted_frequency, flierprops=red_square, vert=False, whis=0.03)
plt.yticks([])
plt.xscale('log')
plt.xlabel('Frequency of Samples')

#plt.xlabel('Frequency of Symbol')
red_triangle = mlines.Line2D([], [], color='darkred', marker='^', linestyle='None',markersize=10, label='LF & HF Samples')
plt.legend(handles=[red_triangle])
plt.savefig('boxPlot.png')


#exponential scale?
#editing

# %% [markdown]
# # Waffle Chart

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

#fig, ax = plt.subplots(figsize=(18,5))

# Let's make a default data frame with catagories and values.
df = pd.DataFrame({ 'catagories': ['High Frequent Samples', 'Normal Samples', 'Low Frequent Samples'], 
                    'values': [323, 64, 13] })
# Now, we define a desired height and width.
waffle_plot_width = 40
waffle_plot_height =10

classes = df['catagories']
values = df['values']

def waffle_plot(classes, values, height, width, colormap):

    # Compute the portion of the total assigned to each class.
    class_portion = [float(v)/sum(values) for v in values]

    # Compute the number of tiles for each catagories.
    total_tiles = width * height
    tiles_per_class = [round(p*total_tiles) for p in class_portion]

    # Make a dummy matrix for use in plotting.
    plot_matrix = np.zeros((height, width))

    # Popoulate the dummy matrix with integer values.
    class_index = 0
    tile_index = 0

    # Iterate over each tile.
    for col in range(waffle_plot_width):
        for row in range(height):
            tile_index += 1

            # If the number of tiles populated is sufficient for this class...
            if tile_index > sum(tiles_per_class[0:class_index]):

                # ...increment to the next class.
                class_index += 1       

            # Set the class value to an integer, which increases with class.
            plot_matrix[row, col] = class_index

    # Create a new figure.
    fig = plt.figure()

    # Using matshow solves your "non-square" problem. 
    plt.matshow(plot_matrix, cmap=colormap)
    plt.colorbar()

    # Get the axis.
    ax = plt.gca()

    # Minor ticks
    ax.set_xticks(np.arange(-.5, (width), 1), minor=True);
    ax.set_yticks(np.arange(-.5, (height), 1), minor=True);

    # Gridlines based on minor ticks
    ax.grid(which='minor', color='w', linestyle='-', linewidth=2)

    # Manually constructing a legend solves your "catagorical" problem.
    legend_handles = []
    for i, c in enumerate(classes):
        lable_str = c
        color_val = colormap(float(i+1)/len(classes))
        legend_handles.append(mpatches.Patch(color=color_val, label=lable_str))

    # Add the legend. Still a bit of work to do here, to perfect centering.
    plt.legend(handles=legend_handles, loc=1, ncol=len(classes),
               bbox_to_anchor=(0.062, -0.1, 0.95, .10))

    plt.xticks([])
    plt.yticks([])
    plt.title('Domination of different type of samples during Training')

# Call the plotting function.
waffle_plot(classes, values, waffle_plot_height, waffle_plot_width,
            plt.cm.coolwarm)
#plt.savefig('waffleChart.png')

# %% [markdown]
# # Word Cloud

# %%
wordCloud = pd.DataFrame({'word':sorted_frequency.index ,
                   'count': counts}) 
data = dict(zip(wordCloud['word'].tolist(), wordCloud['count'].tolist()))
from wordcloud import WordCloud

wc = WordCloud(width=800, height=200, max_words=200,background_color='black').generate_from_frequencies(data)
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 15))
#plt.imshow(wc.recolor(color_func=grey_color_func, random_state=3),interpolation="bilinear")
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.savefig('wordCloud.png')
plt.show()
