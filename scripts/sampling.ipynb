# %%
import pandas as pd

# %%
data = pd.read_csv("/home/jimitcard/Downloads/Sample_1250.csv")
print(data.head())
# Out:
#        Folder Name  tie  clef-C1  clef-G2  keySignature-FM  keySignature-GM  \
# 0  000051652-1_1_1  NaN      1.0      0.0              NaN              NaN
# 1  000051658-1_1_1  NaN      1.0      0.0              NaN              NaN
# 2  000051795-1_1_1  NaN      1.0      0.0              NaN              NaN
# 3  000100015-1_1_1  NaN      1.0      0.0              NaN              NaN
# 4  000100017-7_1_1  NaN      NaN      1.0              1.0              NaN
#
#    keySignature-EbM  keySignature-BbM  keySignature-AbM  timeSignature-C  ...  \
# 0               1.0               NaN               0.0              1.0  ...
# 1               0.0               NaN               1.0              NaN  ...
# 2               NaN               NaN               NaN              NaN  ...
# 3               NaN               1.0               NaN              1.0  ...
# 4               NaN               NaN               NaN              1.0  ...
#
# ...

# %%
df=data.sum(numeric_only=True, axis = 0, skipna = True) 
df
# Out:
# tie                     2.0
# clef-C1                14.0
# clef-G2                32.0
# keySignature-FM         9.0
# keySignature-GM         4.0
# keySignature-EbM        7.0
# keySignature-BbM        9.0
# keySignature-AbM        3.0
# timeSignature-C        23.0
# timeSignature-C/        7.0
# timeSignature-2/4       8.0
# timeSignature-3/4       4.0
# timeSignature-3/8       1.0
# timeSignature-6/8       2.0
# timeSignature-12/8      1.0
# multirest-20            1.0
# multirest-16            1.0
# multirest-10            1.0
# multirest-7             3.0
# multirest-4             2.0
# multirest-2             2.0
# multirest-1             1.0
# barline               142.0
# rest-whole              3.0
# rest-half               9.0
# rest-quarter           16.0
# rest-eighth            17.0
# rest-sixteenth          5.0
# note-Ab3_sixteenth      2.0
# note-A4_whole           2.0
#                       ...
# note-Eb4_eighth         3.0
# note-Eb4_sixteenth     21.0
# ...

# %%
df.sort_values(axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')
# Out:
# note-Ab4_quarter        1.0
# note-D4_quarter         1.0
# note-Eb4_whole          1.0
# note-Eb4_quarter        1.0
# note-E5_whole           1.0
# note-B4_half            1.0
# note-B4_whole           1.0
# note-Bb3_half           1.0
# note-A5_quarter         1.0
# note-A5_half            1.0
# note-Db5_sixteenth      1.0
# note-Ab4_half           1.0
# multirest-1             1.0
# multirest-10            1.0
# multirest-16            1.0
# note-E4_whole           1.0
# timeSignature-12/8      1.0
# timeSignature-3/8       1.0
# note-G4_half            1.0
# multirest-20            1.0
# note-Db5_eighth         2.0
# note-Db5_half           2.0
# note-D5_whole           2.0
# note-G5_half            2.0
# note-C4_eighth          2.0
# note-Bb4_whole          2.0
# note-G4_whole           2.0
# note-A5_eighth          2.0
# note-F4_whole           2.0
# tie                     2.0
#                       ...
# note-F4_quarter        10.0
# note-B4_quarter        10.0
# ...

# %%
df['tie']
# Out:
# 2.0

# %%
data = data.drop("Unnamed: 110", axis=1)
data = data.drop("Unnamed: 111", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-caa4eca07e31> in <module>()
# ----> 1 data = data.drop("Unnamed: 110", axis=1)
#       2 data = data.drop("Unnamed: 111", axis=1)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
sorted_frequency=pd.DataFrame(df)
print(sorted_frequency)
df_t=sorted_frequency.T
df_t
# Out:
#                         0
# tie                   2.0
# clef-C1              14.0
# clef-G2              32.0
# keySignature-FM       9.0
# keySignature-GM       4.0
# keySignature-EbM      7.0
# keySignature-BbM      9.0
# keySignature-AbM      3.0
# timeSignature-C      23.0
# timeSignature-C/      7.0
# timeSignature-2/4     8.0
# timeSignature-3/4     4.0
# timeSignature-3/8     1.0
# timeSignature-6/8     2.0
# timeSignature-12/8    1.0
# multirest-20          1.0
# multirest-16          1.0
# multirest-10          1.0
# multirest-7           3.0
# multirest-4           2.0
# multirest-2           2.0
# multirest-1           1.0
# barline             142.0
# rest-whole            3.0
# rest-half             9.0
# rest-quarter         16.0
# rest-eighth          17.0
# rest-sixteenth        5.0
# note-Ab3_sixteenth    2.0
# note-A4_whole         2.0
# ...                   ...
# note-Eb4_eighth       3.0
# note-Eb4_sixteenth   21.0
# note-E5_whole         1.0
# ...

# %%
for col in df_t.columns: 
    print(col)
# Out:
# tie
# clef-C1
# clef-G2
# keySignature-FM
# keySignature-GM
# keySignature-EbM
# keySignature-BbM
# keySignature-AbM
# timeSignature-C
# timeSignature-C/
# timeSignature-2/4
# timeSignature-3/4
# timeSignature-3/8
# timeSignature-6/8
# timeSignature-12/8
# multirest-20
# multirest-16
# multirest-10
# multirest-7
# multirest-4
# multirest-2
# multirest-1
# barline
# rest-whole
# rest-half
# rest-quarter
# rest-eighth
# rest-sixteenth
# note-Ab3_sixteenth
# note-A4_whole
# note-A4_half
# note-A4_quarter
# note-A4_eighth
# note-A4_sixteenth
# note-Ab4_half
# note-Ab4_quarter
# note-Ab4_eighth
# note-Ab4_sixteenth
# note-A5_half
# note-A5_quarter
# note-A5_eighth
# note-A5_sixteenth
# note-Bb3_half
# note-Bb3_sixteenth
# note-B4_whole
# note-B4_half
# note-B4_quarter
# note-B4_eighth
# note-B4_sixteenth
# note-Bb4_whole
# note-Bb4_half
# note-Bb4_quarter
# note-Bb4_eighth
# note-Bb4_sixteenth
# note-C4_half
# note-C4_eighth
# note-C4_sixteenth
# note-C5_half
# note-C5_quarter
# ...

# %%
vocabulary={}
set_vocabulary=set(vocabulary)
for col in df_t.columns: 
    print(col) 
    set_vocabulary.add(col.strip())
set_vocabulary
# Out:
# tie
# clef-C1
# clef-G2
# keySignature-FM
# keySignature-GM
# keySignature-EbM
# keySignature-BbM
# keySignature-AbM
# timeSignature-C
# timeSignature-C/
# timeSignature-2/4
# timeSignature-3/4
# timeSignature-3/8
# timeSignature-6/8
# timeSignature-12/8
# multirest-20
# multirest-16
# multirest-10
# multirest-7
# multirest-4
# multirest-2
# multirest-1
# barline
# rest-whole
# rest-half
# rest-quarter
# rest-eighth
# rest-sixteenth
# note-Ab3_sixteenth
# note-A4_whole
# note-A4_half
# note-A4_quarter
# note-A4_eighth
# note-A4_sixteenth
# note-Ab4_half
# note-Ab4_quarter
# note-Ab4_eighth
# note-Ab4_sixteenth
# note-A5_half
# note-A5_quarter
# note-A5_eighth
# note-A5_sixteenth
# note-Bb3_half
# note-Bb3_sixteenth
# note-B4_whole
# note-B4_half
# note-B4_quarter
# note-B4_eighth
# note-B4_sixteenth
# note-Bb4_whole
# note-Bb4_half
# note-Bb4_quarter
# note-Bb4_eighth
# note-Bb4_sixteenth
# note-C4_half
# note-C4_eighth
# note-C4_sixteenth
# note-C5_half
# note-C5_quarter
# ...

# %%
list_vocabulary=list(set_vocabulary)
list_vocabulary
# Out:
# ['note-C5_quarter',
#  'note-G4_eighth',
#  'note-Ab4_sixteenth',
#  'note-A5_eighth',
#  'note-E5_sixteenth',
#  'note-G5_sixteenth',
#  'note-D5_eighth',
#  'note-Bb4_whole',
#  'note-E4_half',
#  'note-B4_sixteenth',
#  'note-C5_sixteenth',
#  'note-Eb4_half',
#  'note-Bb4_eighth',
#  'note-C5_eighth',
#  'note-G5_eighth',
#  'rest-whole',
#  'note-F5_whole',
#  'note-Bb3_sixteenth',
#  'note-Eb4_quarter',
#  'note-F4_eighth',
#  'note-Ab4_quarter',
#  'rest-quarter',
#  'note-Bb4_quarter',
#  'note-D5_sixteenth',
#  'rest-half',
#  'note-G5_half',
#  'note-Eb4_eighth',
#  'note-B4_half',
#  'keySignature-EbM',
#  'multirest-4',
#  'multirest-7',
#  'multirest-1',
#  'multirest-2',
#  'timeSignature-12/8',
#  'note-C4_half',
#  'note-D4_quarter',
#  'note-Eb4_whole',
#  'note-Eb5_quarter',
#  'note-B4_whole',
#  'note-F5_half',
#  'note-Db5_sixteenth',
#  'note-A5_half',
#  'note-F5_eighth',
#  'note-A5_quarter',
#  'note-C4_sixteenth',
#  'multirest-20',
#  'keySignature-AbM',
# ...

# %%
f = open("/home/jimitcard/Desktop/OMR/dataset/primusCalvoRizoAppliedSciences2018/package_aa/000051652-1_1_1/000051652-1_1_1.semantic", "r")
data=f.read().strip().split("\t")
print(data)
f.close()
flag=True
for note in data:
    print(note in set_vocabulary)
    if not (note in set_vocabulary):
        flag=False
        #print(note)
print(flag)
if flag!=False:
    print('add this element')
# Out:
# ['clef-C1', 'keySignature-EbM', 'timeSignature-C', 'multirest-4', 'barline', 'rest-half', 'note-G4_eighth', 'note-G4_sixteenth', 'note-G4_sixteenth', 'note-G4_eighth', 'note-A4_eighth', 'barline', 'note-B4_eighth', 'note-Bb4_eighth', 'rest-eighth', 'note-Bb4_eighth', 'note-Bb4_eighth', 'note-Bb4_eighth', 'note-A4_eighth', 'note-Bb4_eighth', 'barline', 'note-G4_quarter']
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# add this element

# %%
'note-G4_quarter' in set_vocabulary
# Out:
# True

# %%
f = open("/home/jimitcard/Desktop/OMR/dataset/primusCalvoRizoAppliedSciences2018/package_aa/list.txt", "r")
samples_aa=f.read().strip().split("\n")
f.close()
print(len(samples_aa))
# Out:
# 43594

# %%
root_dir_aa="/home/jimitcard/Desktop/OMR/dataset/primusCalvoRizoAppliedSciences2018/package_aa/"

# %%
#for package_aa
sample_list=[]
for sample in samples_aa:
    f = open(root_dir_aa+sample+"/"+sample+".semantic", "r")
    #print(root_dir+sample+"/"+sample+".semantic")
    data=f.read().strip().split("\t")
    #print(data)
    flag=True
    for note in data:
        if not (note in set_vocabulary):
            flag=False
           #print(note)
    #print(flag)
    if flag!=False:
        print('add this element '+sample)
        sample_list.append(sample)
len(sample_list)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-17-20f80d907072> in <module>()
#       2 sample_list=[]
#       3 for sample in samples_aa:
# ----> 4     f = open(root_dir_aa+sample+"/"+sample+".semantic", "r")
#       5     #print(root_dir+sample+"/"+sample+".semantic")
#       6     data=f.read().strip().split("\t")
#
# IOError: [Errno 2] No such file or directory: '/home/jimitcard/Desktop/OMR/dataset/primusCalvoRizoAppliedSciences2018/package_aa/000051652-1_1_1/000051652-1_1_1.semantic'

# %%
sample_list=[]
f = open('/home/jimitcard/Desktop/OMR/sample_2500/sample_list.txt', "r")
sample_list=f.read().strip().split("\n")

# %%
sample_2500 = pd.DataFrame(index=sample_list, columns=list_vocabulary)
sample_2500 = sample_2500.fillna(0) # with 0s rather than NaNs
sample_2500.head()
# Out:
#                  note-C5_quarter  note-G4_eighth  note-Ab4_sixteenth  \
# 000051652-1_1_1                0               0                   0
# 000051761-1_1_1                0               0                   0
# 000051771-1_1_1                0               0                   0
# 000051779-1_1_1                0               0                   0
# 000051795-1_1_1                0               0                   0
#
#                  note-A5_eighth  note-E5_sixteenth  note-G5_sixteenth  \
# 000051652-1_1_1               0                  0                  0
# 000051761-1_1_1               0                  0                  0
# 000051771-1_1_1               0                  0                  0
# 000051779-1_1_1               0                  0                  0
# 000051795-1_1_1               0                  0                  0
#
#                  note-D5_eighth  note-Bb4_whole  note-E4_half  \
# 000051652-1_1_1               0               0             0
# ...

# %%
#moving samples to a new location

# importing os module  
import os  
  
# importing shutil module  
import shutil 

root_dir_aa="/home/jimitcard/Desktop/OMR/dataset/primusCalvoRizoAppliedSciences2018/package_aa/"
destination="/home/jimitcard/Desktop/OMR/sample_2500"

for sample in sample_list:
    #source
    source=root_dir_aa+sample
    dest = shutil.move(source, destination)

print(os.listdir(destination))
# Out:
# ['000110650-1_1_1', '000108456-1_1_1', '000113956-1_1_1', '000104082-1_1_1', '000115618-1_1_1', '000103053-1_1_1', '000123182-10_1_1', '000102931-1_1_1', '000132415-1_1_1', '000137138-1_5_1', '000113287-1_1_1', '000128145-1_2_1', '000118490-1_1_1', '000113477-1_1_1', '000104415-1_1_1', '000108241-1_1_1', '100029496-1_1_1', '000109660-1_1_1', '000113980-1_1_1', '100500714-1_1_1', '000105668-1_1_1', '000114078-1_1_2', '000128929-5_1_1', '000135616-1_1_1', '000131612-1_1_2', '000114161-1_1_2', '000130459-1_1_1', '000123961-1_1_1', '110000268-1_1_1', '000129055-1_1_2', '000126788-1_1_1', '000128057-1_1_1', '000135036-1_1_1', '100500993-1_12_1', '000119115-1_1_1', '000125088-12_1_1', '000100593-1_1_1', '000102798-1_1_1', '000109517-1_1_1', '000105804-1_1_1', '100030470-1_1_1', '000108104-1_1_2', '000119101-1_3_1', '000122001-1_1_1', '110000934-1_1_1', '000106159-1_1_1', '000111859-8_1_1', '000123321-1_1_1', '000127323-1_1_1', '000126056-1_1_1', '000102548-1_1_1', '000124117-1_1_1', '10050
# ...

# %%
sample_2500_path="/home/jimitcard/Desktop/OMR/sample_2500/"
for sample in sample_list:
    f = open(sample_2500_path+sample+"/"+sample+".semantic", "r")
    #print(root_dir+sample+"/"+sample+".semantic")
    notes=f.read().strip().split("\t")
    for note in notes:
        sample_2500.loc[sample,note] += 1
    
sample_2500.head()
# Out:
#                  note-C5_quarter  note-G4_eighth  note-Ab4_sixteenth  \
# 000051652-1_1_1                0               2                   0
# 000051761-1_1_1                0               0                   0
# 000051771-1_1_1                1               1                   0
# 000051779-1_1_1                0               0                   0
# 000051795-1_1_1                0               1                   0
#
#                  note-A5_eighth  note-E5_sixteenth  note-G5_sixteenth  \
# 000051652-1_1_1               0                  0                  0
# 000051761-1_1_1               0                  1                  0
# 000051771-1_1_1               0                  0                  0
# 000051779-1_1_1               0                  0                  0
# 000051795-1_1_1               0                  0                  0
#
#                  note-D5_eighth  note-Bb4_whole  note-E4_half  \
# 000051652-1_1_1               0               0             0
# ...

# %%
dropnote='note-Ab4_sixteenth'

# %%
drop_list=[]
for sample in sample_list:
    if sample_2500.loc[sample,dropnote]>=1:
        drop_list.append(sample)
len(drop_list)
# Out:
# 53

# %%
sample_2500=sample_2500.drop(drop_list)

# %%
sample_list=sample_2500.index

# %%
sample_2500=sample_2500.drop(dropnote, axis=1)

# %%
sample_2500
# Out:
#                   note-C5_quarter  note-G4_eighth  note-A5_eighth  \
# 000051761-1_1_1                 0               0               0
# 000051771-1_1_1                 1               1               0
# 000051796-1_1_1                 0               0               0
# 000100038-1_1_1                 0               0               0
# 000100040-1_2_1                 2               1               0
# 000100056-1_3_1                 0               0               0
# 000100064-1_1_1                 0               0               0
# 000100081-1_1_1                 0               0               0
# 000100085-1_1_1                 0               0               2
# 000100115-1_1_1                 0               2               0
# 000100140-1_1_1                 0               4               0
# 000100154-1_1_1                 0               6               0
# 000100162-1_1_1                 0               1               0
# ...

# %%
frequency_of_notes=sample_2500.sum(numeric_only=True, axis = 0, skipna = True) 
sorted_frequency=frequency_of_notes.sort_values(axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last')
sorted_frequency
# Out:
# barline               4434
# note-C5_eighth        2592
# note-D5_eighth        1737
# note-C5_sixteenth     1487
# note-G4_eighth        1459
# note-A4_eighth        1298
# note-D5_sixteenth     1230
# note-B4_eighth        1004
# note-Bb4_eighth        966
# rest-eighth            929
# clef-G2                905
# note-E5_eighth         887
# note-E5_sixteenth      781
# note-A4_sixteenth      754
# note-G4_sixteenth      740
# note-F5_eighth         733
# note-F4_eighth         670
# note-C5_quarter        666
# note-F5_sixteenth      642
# rest-quarter           632
# note-B4_sixteenth      622
# timeSignature-C        580
# note-Bb4_sixteenth     557
# note-F4_sixteenth      508
# note-G5_eighth         480
# clef-C1                461
# keySignature-FM        349
# note-G5_sixteenth      348
# note-A4_quarter        330
# timeSignature-2/4      304
# note-G4_quarter        296
# note-Eb5_eighth        274
# note-Bb4_quarter       256
# note-E4_sixteenth      246
# ...

# %%
sorted_frequency.describe()
# Out:
# count      60.000000
# mean      560.183333
# std       706.677749
# min        55.000000
# 25%       147.250000
# 50%       300.000000
# 75%       734.750000
# max      4434.000000
# dtype: float64

# %%
len(sample_list)
# Out:
# 2043

# %%
frequency_of_notes=sample_2500.sum(numeric_only=True, axis = 0, skipna = True) 
frequency_of_notes
# Out:
# note-C5_quarter       1200
# note-G4_eighth        2135
# note-Ab4_sixteenth     167
# note-A5_eighth         158
# note-E5_sixteenth      866
# note-G5_sixteenth      411
# note-D5_eighth        2407
# note-Bb4_whole          30
# note-E4_half            38
# note-B4_sixteenth      729
# note-C5_sixteenth     1858
# note-Eb4_half           38
# note-Bb4_eighth       1633
# note-C5_eighth        3618
# note-G5_eighth         619
# note-Bb3_sixteenth      47
# note-Eb4_quarter       118
# note-F4_eighth         979
# note-Ab4_quarter       107
# rest-quarter          1342
# note-Bb4_quarter       614
# note-D5_sixteenth     1473
# rest-half              431
# note-G5_half            58
# note-Eb4_eighth        229
# note-B4_half           121
# keySignature-EbM       283
# multirest-4             71
# multirest-7             51
# multirest-1            158
#                       ...
# timeSignature-3/8      164
# timeSignature-3/4      266
# note-F5_quarter        327
# ...

# %%
sorted_frequency=frequency_of_notes.sort_values(axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last')

# %%
sorted_frequency
# Out:
# barline               8728
# note-C5_eighth        3723
# note-D5_eighth        2459
# note-G4_eighth        2174
# note-C5_sixteenth     1905
# note-A4_eighth        1816
# note-Bb4_eighth       1695
# rest-eighth           1575
# note-D5_sixteenth     1498
# clef-G2               1476
# rest-quarter          1401
# note-B4_eighth        1324
# note-C5_quarter       1230
# timeSignature-C       1159
# note-E5_eighth        1135
# note-G4_sixteenth     1081
# note-F5_eighth        1058
# note-F4_eighth        1008
# clef-C1               1001
# note-A4_sixteenth      952
# note-Bb4_sixteenth     938
# note-E5_sixteenth      874
# note-F4_sixteenth      809
# note-F5_sixteenth      777
# note-G4_quarter        766
# note-B4_sixteenth      748
# note-A4_quarter        743
# note-Bb4_quarter       638
# note-G5_eighth         638
# keySignature-FM        634
#                       ...
# note-D4_quarter         74
# multirest-4             72
# note-G5_half            66
# ...

# %%
sorted_frequency.describe()
# Out:
# count      99.000000
# mean      578.656566
# std      1010.589555
# min        16.000000
# 25%        90.500000
# 50%       269.000000
# 75%       750.000000
# max      8431.000000
# dtype: float64

# %%
type(frequency_of_notes.index)
# Out:
# pandas.core.indexes.base.Index

# %%
#x axis
notes=frequency_of_notes.index.tolist()
notes
# Out:
# ['note-C5_quarter',
#  'note-G4_eighth',
#  'note-Ab4_sixteenth',
#  'note-A5_eighth',
#  'note-E5_sixteenth',
#  'note-G5_sixteenth',
#  'note-D5_eighth',
#  'note-Bb4_whole',
#  'note-E4_half',
#  'note-B4_sixteenth',
#  'note-C5_sixteenth',
#  'note-Eb4_half',
#  'note-Bb4_eighth',
#  'note-C5_eighth',
#  'note-G5_eighth',
#  'rest-whole',
#  'note-F5_whole',
#  'note-Bb3_sixteenth',
#  'note-Eb4_quarter',
#  'note-F4_eighth',
#  'note-Ab4_quarter',
#  'rest-quarter',
#  'note-Bb4_quarter',
#  'note-D5_sixteenth',
#  'rest-half',
#  'note-G5_half',
#  'note-Eb4_eighth',
#  'note-B4_half',
#  'keySignature-EbM',
#  'multirest-4',
#  'multirest-7',
#  'multirest-1',
#  'multirest-2',
#  'timeSignature-12/8',
#  'note-C4_half',
#  'note-D4_quarter',
#  'note-Eb4_whole',
#  'note-Eb5_quarter',
#  'note-B4_whole',
#  'note-F5_half',
#  'note-Db5_sixteenth',
#  'note-A5_half',
#  'note-F5_eighth',
#  'note-A5_quarter',
#  'note-C4_sixteenth',
#  'multirest-20',
#  'keySignature-AbM',
# ...

# %%
#y axis
notes_frequency=[]
for frequency in frequency_of_notes:
    notes_frequency.append(frequency)
notes_frequency
# Out:
# [1230,
#  2174,
#  177,
#  162,
#  874,
#  418,
#  2459,
#  37,
#  50,
#  748,
#  1905,
#  42,
#  1695,
#  3723,
#  638,
#  21,
#  17,
#  47,
#  121,
#  1008,
#  117,
#  1401,
#  638,
#  1498,
#  486,
#  66,
#  232,
#  145,
#  297,
#  72,
#  51,
#  163,
#  101,
#  16,
#  30,
#  74,
#  2,
#  127,
#  21,
#  115,
#  18,
#  15,
#  1058,
#  75,
#  233,
#  10,
#  29,
#  133,
#  766,
#  213,
#  353,
#  352,
#  184,
#  952,
#  938,
#  3,
#  1001,
#  1324,
#  1159,
#  8728,
#  2,
#  116,
#  809,
#  634,
#  377,
#  116,
#  156,
#  14,
#  37,
#  295,
#  275,
#  377,
#  409,
#  241,
#  293,
#  743,
#  167,
#  272,
#  348,
#  50,
#  41,
#  256,
#  304,
#  248,
#  80,
#  777,
#  312,
#  22,
#  16,
#  5,
#  268,
#  568,
#  290,
#  1575,
#  327,
#  349,
#  58,
#  76,
#  46,
#  1081,
#  1135,
#  1476,
#  192,
#  134,
#  27,
#  343,
#  1816,
#  320]

# %%
print(plt.style.available)
mpl.style.use(["seaborn-whitegrid"]) # seaborn-ticks seaborn-whitegrid seaborn-white
# Out:
# ['seaborn-darkgrid', 'Solarize_Light2', 'seaborn-notebook', 'classic', 'seaborn-ticks', 'grayscale', 'bmh', 'seaborn-talk', 'dark_background', 'ggplot', 'fivethirtyeight', '_classic_test', 'seaborn-colorblind', 'seaborn-deep', 'seaborn-whitegrid', 'seaborn', 'seaborn-poster', 'seaborn-bright', 'seaborn-muted', 'seaborn-paper', 'seaborn-white', 'fast', 'seaborn-pastel', 'seaborn-dark', 'tableau-colorblind10', 'seaborn-dark-palette']

# %%
# we are using the inline backend
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# ('Matplotlib version: ', '2.2.5')

# %%
sorted_frequency.head()
# Out:
# barline              8728
# note-C5_eighth       3723
# note-D5_eighth       2459
# note-G4_eighth       2174
# note-C5_sixteenth    1905
# dtype: int64

# %%
sorted_frequency.plot(kind='line')

plt.title('Frequency Distribution of notes in the sampled Dataset- 1250')
plt.ylabel('Frequency')
plt.xlabel('Notes')
plt.xticks([])
plt.savefig('frequencyVsNotes.png')
#plt.plot([5,0], [5,4500], 'k-')
#plt.yscale('log')
#median
#10-90
plt.show()

# %%
SMALL_SIZE = 14
MEDIUM_SIZE = 9
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
sorted_frequency.plot()

# %%
sorted_frequency.plot(kind='box', figsize=(8, 8))

plt.title('Box plot')
plt.ylabel('frequency')

plt.show()

# %%
red_square = dict(markerfacecolor='r', marker='o')
fig6, ax6 = plt.subplots()
ax6.set_title('Box Plot demonstrating Outliers in the form of HF and LF')
ax6.boxplot(sorted_frequency, flierprops=red_square, vert=False, whis=0.10)
plt.yticks([])

plt.xscale('log')
plt.savefig('boxPlot.png')

#exponential scale?
#editing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b6e28fe5ae2b> in <module>()
#       1 red_square = dict(markerfacecolor='r', marker='o')
# ----> 2 fig6, ax6 = plt.subplots()
#       3 ax6.set_title('Box Plot demonstrating Outliers in the form of HF and LF')
#       4 ax6.boxplot(sorted_frequency, flierprops=red_square, vert=False, whis=0.10)
#       5 plt.yticks([])
#
# NameError: name 'plt' is not defined

# %%
sorted_frequency.describe()
# Out:
# count      60.000000
# mean      560.183333
# std       706.677749
# min        55.000000
# 25%       147.250000
# 50%       300.000000
# 75%       734.750000
# max      4434.000000
# dtype: float64

# %%
frequency_of_notes['tie']
# Out:
# 327

# %%
df_t['tie']['000100405-1_1_1']=3
df_t['tie']['000100405-1_1_1']
df_t[1]
# Out:
#   File "<ipython-input-112-c027dcde1aab>", line 3
#     df_t[1][]
#             ^
# SyntaxError: invalid syntax

# %%
df_t.insert(loc=0, column='Folder',value)
# Out:
#   File "<ipython-input-114-1c63a74cc9c1>", line 1
#     df_t.insert(loc=0, column='Folder',value)
# SyntaxError: non-keyword arg after keyword arg

# %%
sample_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-49cdd354e4f7> in <module>()
# ----> 1 sample_list
#
# NameError: name 'sample_list' is not defined

# %%
for col in sorted_frequency.columns: 
    print(df[col])
# Out:
# 2.0

# %%
data.columns
# Out:
# Index([u'Folder Name', u'tie', u'clef-C1', u'clef-G2', u'keySignature-FM',
#        u'keySignature-GM', u'keySignature-EbM', u'keySignature-BbM',
#        u'keySignature-AbM', u'timeSignature-C',
#        ...
#        u'note-F5_sixteenth', u'note-G4_whole', u'note-G4_half',
#        u'note-G4_quarter', u'note-G4_eighth', u'note-G4_sixteenth',
#        u'note-G5_half', u'note-G5_quarter', u'note-G5_eighth',
#        u'note-G5_sixteenth'],
#       dtype='object', length=110)

# %%
frquency_symbol = {'symbol': [], 
        'frequency':[] } 
df = pd.DataFrame(frquency_symbol) 
df.head()
# Out:
# Empty DataFrame
# Columns: [frequency, symbol]
# Index: []

# %%
for col in df.columns: 
    print(df[col])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-9ee6dc0eb0e7> in <module>()
# ----> 1 for col in df.columns:
#       2     print(df[col])
#       3
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
for i in len(total)
# Out:
# timeSignature-C/    7.0
# dtype: float64

# %%
data.dtypes
# Out:
# Folder Name            object
# tie                   float64
# clef-C1               float64
# clef-G2               float64
# keySignature-FM       float64
# keySignature-GM       float64
# keySignature-EbM      float64
# keySignature-BbM      float64
# keySignature-AbM      float64
# timeSignature-C       float64
# timeSignature-C/      float64
# timeSignature-2/4     float64
# timeSignature-3/4     float64
# timeSignature-3/8     float64
# timeSignature-6/8     float64
# timeSignature-12/8    float64
# multirest-20          float64
# multirest-16          float64
# multirest-10          float64
# multirest-7           float64
# multirest-4           float64
# multirest-2           float64
# multirest-1           float64
# barline               float64
# rest-whole            float64
# rest-half             float64
# rest-quarter          float64
# rest-eighth           float64
# rest-sixteenth        float64
# note-Ab3_sixteenth    float64
#                        ...
# ...

# %%
sample_list_2000_80=sample_list
len(sample_list_2000_80)
# Out:
# 2043
